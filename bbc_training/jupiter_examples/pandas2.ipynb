# %%
import pandas as pd

# %%
df = pd.read_csv('athletes.csv')

# %%
df
# Out:
#               id nationality     sex  height  weight          sport gold  \
# 0      736041664         ESP    male    1.72    64.0      athletics    0
# 1      532037425         KOR  female    1.68    56.0        fencing    0
# 2      435962603         CAN    male    1.98    79.0      athletics    0
# 3      521041435         MDA    male    1.83    80.0      taekwondo    0
# 4       33922579         NZL    male    1.81    71.0        cycling    0
# ...          ...         ...     ...     ...     ...            ...  ...
# 11538  265605954         CUB  female    1.64    58.0      athletics    0
# 11539  214461847         CZE  female    1.73    63.0      athletics    0
# 11540   88361042         CHN    male    1.85   100.0      wrestling    0
# 11541  900065925         VIE    male    1.60    56.0  weightlifting    0
# 11542  711404576         RSA    male    1.85    70.0      athletics    0
#
#       silver bronze
# 0          0      0
# 1          0      0
# 2          0      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11543 entries, 0 to 11542
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           11543 non-null  int64
#  1   nationality  11543 non-null  object
#  2   sex          11543 non-null  object
#  3   height       11213 non-null  float64
#  4   weight       10884 non-null  float64
#  5   sport        11543 non-null  object
#  6   gold         11543 non-null  object
#  7   silver       11543 non-null  object
#  8   bronze       11543 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 811.7+ KB

# %%
df.describe()
# Out:
#                  id        height        weight
# count  1.154300e+04  11213.000000  10884.000000
# mean   4.999553e+08      1.766294     72.068357
# std    2.909114e+08      0.112702     16.174702
# min    1.834700e+04      1.210000     31.000000
# 25%    2.450554e+08      1.690000     60.000000
# 50%    5.001905e+08      1.760000     70.000000
# 75%    7.540569e+08      1.840000     81.000000
# max    9.999878e+08      2.210000    170.000000

# %%
df['height']
# Out:
# 0        1.72
# 1        1.68
# 2        1.98
# 3        1.83
# 4        1.81
#          ...
# 11538    1.64
# 11539    1.73
# 11540    1.85
# 11541    1.60
# 11542    1.85
# Name: height, Length: 11543, dtype: float64

# %%
df['height'].sum()
# Out:
# 19805.46

# %%
# standard deviation
df['height'].std()
# Out:
# 0.11270232356880054

# %%
df['height'].plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
df['height'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['height'].plot.scatter(x='weight', y='')
